# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushrut0202/CIIMS/blob/main/AMR_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-839ecfdb-0958-40f3-9ad8-0f42e0ffaa08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-839ecfdb-0958-40f3-9ad8-0f42e0ffaa08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel("/content/AMR_long_format.xlsx")
df.columns.tolist()
# Out:
# ['Unnamed: 0', 'Unnamed: 1']

# %%
import pandas as pd

# Load entire sheet WITHOUT assuming header row
df_raw = pd.read_excel("/content/AMR_long_format.xlsx", header=None)

df_raw.head(20)
# Out:
#                0                      1
# 0            NaN                    NaN
# 1            NaN                    NaN
# 2     Row Labels  Count of Institute ID
# 3    A.baumannii                      8
# 4        E. coli                     57
# 5  K. pneumoniae                     32
# 6         Others                     31
# 7  P. aeruginosa                     24
# 8      S. aureus                     47
# 9    Grand Total                    199

# %%
import pandas as pd

xls = pd.ExcelFile("/content/AMR_long_format.xlsx")

xls.sheet_names
# Out:
# ['Sheet2', 'Sheet3', 'Sheet4', 'Sheet1']

# %%
import pandas as pd

xls = pd.ExcelFile("/content/AMR_long_format.xlsx")

for sheet in xls.sheet_names:
    print("----", sheet, "----")
    df_temp = pd.read_excel("/content/AMR_long_format.xlsx", sheet_name=sheet, header=None)
    print(df_temp.head(20))
    print("\n")
# Out:
# ---- Sheet2 ----
#                0                      1
# 0            NaN                    NaN
# 1            NaN                    NaN
# 2     Row Labels  Count of Institute ID
# 3    A.baumannii                      8
# 4        E. coli                     57
# 5  K. pneumoniae                     32
# 6         Others                     31
# 7  P. aeruginosa                     24
# 8      S. aureus                     47
# 9    Grand Total                    199
#
#
# ---- Sheet3 ----
#                        0              1               2      3      4     5   \
# 0                     NaN            NaN             NaN    NaN    NaN   NaN
# 1                     NaN            NaN             NaN    NaN    NaN   NaN
# 2   Count of Institute ID  Column Labels             NaN    NaN    NaN   NaN
# 3              Row Labels    Animal Feed  Drinking water  Fecal  Human  Milk
# 4             A.baumannii            NaN             NaN      1      1     1
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b2fcf58-1577-4b88-9db7-4d5d64c5c0f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b2fcf58-1577-4b88-9db7-4d5d64c5c0f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

xls = pd.ExcelFile("/content/For_AMR_Dashboard.xlsx")
xls.sheet_names
# Out:
# ['Sheet1']

# %%
for sheet in xls.sheet_names:
    print("----", sheet, "----")
    df_temp = pd.read_excel("/content/For_AMR_Dashboard.xlsx", sheet_name=sheet, header=None)
    print(df_temp.head(10))
    print("\n")
# Out:
# ---- Sheet1 ----
#        0              1      2           3              4        5
# 0  Sr.No   Institute ID   Type  Resistance       Pathogen  Present
# 1      1  CIIMS/AMR/001  Human           3  K. pneumoniae      yes
# 2      2  CIIMS/AMR/002  Human           1      S. aureus      yes
# 3      3  CIIMS/AMR/003  Human           1      S. aureus      yes
# 4      4  CIIMS/AMR/004  Human           3        E. coli      yes
# 5      5  CIIMS/AMR/005  Human           4      S. aureus      yes
# 6      6  CIIMS/AMR/006  Human           5        E. coli      yes
# 7      7  CIIMS/AMR/007  Human           0        E. coli      yes
# 8      8  CIIMS/AMR/008  Human           5        E. coli      yes
# 9      9  CIIMS/AMR/009  Human           0        E. coli      yes
